# %%
import pandas as pd
import scipy.stats
import statsmodels.stats.power

# %%
data= pd.DataFrame(data=[[1,57,62],[2,103,122],[3,59,54],[4,75,82],[5,84,84],[6,73,86],[7,35,32],[8,110,104],[9,44,38],[10,82,107],
[11,67,84],[12,64,85],[13,78,99],[14,53,39],[15,41,34],[16,39,58],[17,80,73],[18,87,53],[19,73,66],[20,65,78],
[21,28,41],[22,62,71],[23,49,38],[24,84,95],[25,63,81],[26,77,58],[27,67,75],[28,101,94],[29,91,100],[30,50,68]],columns=['SALESPERSON','Old_Scheme','New_Scheme'])

# %% [markdown]
# Q1 Find the mean of old scheme and new scheme column. (5 points)

# %%
data[['Old_Scheme','New_Scheme']].mean()
# Out:
# Old_Scheme    68.033333
# New_Scheme    72.033333
# dtype: float64

# %% [markdown]
# Q2 Use the five percent significance test over the data to determine the p value to check new scheme has significantly raised outputs? (10 points)

# %%
t,p=scipy.stats.ttest_rel(data.Old_Scheme,data.New_Scheme)
p
# Out:
# 0.13057553961337662

# %%
t
# Out:
# -1.5559143823544377

# %% [markdown]
# Q3 What conclusion does the test (p-value) lead to? (2.5 points)

# %% [markdown]
# A3 If null hypothesis is deifned as H0 : new scheme has not improved the sales(mean1=mean2)
#                                     H1 : new scheme has improved the sales(mean2>mean1)
# Since p value is more than 0.025 and t value is slightly greater than -1.6 it is concluded that H1 is True.

# %% [markdown]
# Q4 Suppose it has been calculated that in order for Titan to break even, the average output must increase by £5000 in the scheme compared to the old scheme. If this figure is alternative hypothesis, what is:
#
#         a) The probability of a type 1 error? (2.5 points)
#
#         b) What is the p- value of the hypothesis test if we test for a difference of $5000? (10 points)
#
#         c) Power of the test (5 points)

# %%
one_s_t,one_s_p = scipy.stats.ttest_1samp(data.New_Scheme,data.Old_Scheme.mean()+5)
powe = statsmodels.stats.power.TTestPower()
p_w=powe.power(effect_size=(data.New_Scheme.std()/(data.Old_Scheme.mean()+5)),nobs=30,alpha=(1-one_s_p))
print('a) probability of type 1 error {}'.format(1-one_s_p))
print('b) p- value {}'.format(one_s_p))
print('c) power of test {}'.format(p_w))
# Out:
# a) probability of type 1 error 0.17846573386245557
# b) p- value 0.8215342661375444
# c) power of test 0.6675438567782409
